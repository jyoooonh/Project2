# %%
import pandas as pd

# %%
listed = pd.read_csv('../1.데이터셋/4.상장_Clean_Feature.csv')
listed
# Out:
#               회사명   거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        (주)CMG제약   58820  2022                19                 79
# 1         (주)ES큐브   50120  2020                 3                270
# 2        (주)MH에탄올   23150  2022                 6                  9
# 3        (주)강원에너지  114190  2018               -16                -28
# 4        (주)고려시멘트  198440  2022                 0                  7
# ..            ...     ...   ...               ...                ...
# 725     (주)한중엔시에스  107640  2016                 2                  2
# 726     도부마스크 (주)  227420  2018               -28                -77
# 727  에이치엔에스하이텍(주)   44990  2021                13                 44
# 728     에이펙스인텍(주)  207490  2022                 3                  4
# 729       태양기계(주)  116100  2022                27                  3
#
#      CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  유동비율  당좌비율  부채비율  ...  \
# 0                    2                  6   617   520    15  ...
# ...

# %%
unlisted = pd.read_csv('../1.데이터셋/4.비상장_Clean_Feature.csv')
unlisted
# Out:
#             회사명  거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        주식회사성환  81567  2019              7.09              17.07
# 1        주식회사성후  86355  2022              8.06              22.99
# 2      주식회사성훈철강  56923  2022             23.22              30.13
# 3        주식회사성희  63893  2021            -11.77             -12.62
# 4      주식회사성희산업  75992  2018             75.47             120.92
# ...         ...    ...   ...               ...                ...
# 20300  주식회사나노브릭  77738  2017            -14.23             -27.59
# 20301   주식회사나노아  67623  2017           -153.85               0.00
# 20302  주식회사나노앤텍  72817  2022              0.76               0.85
# 20303   주식회사나노코  56825  2022             28.06              38.70
# 20304   주식회사나노팜  29937  2019             29.25               0.00
#
#        CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율    유동비율    당좌비율     부채비율  ...  \
# 0                   0.56              13.70   30.42   30.42     8.61  ...
# ...

# %%
unlisted.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율',
#        'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '유동비율', '당좌비율', '부채비율',
#        '유동부채비율', '차입금의존도', '순운전자본비율', '현금비율', '유동자산구성비율', '자기자본구성비율',
#        '자기자본순이익률', '경영자본순이익률', '매출액순이익률', '총자본사업이익률', '총자본영업이익률', '매출액영업이익률',
#        '금융비용부담률', 'CROE', '총자산증가율', '총자본증가율', '유동자산증가율', '비유동자산증가율', '매출액증가율',
#        '유형자산증가율', '부가가치', '총자본투자효율', '설비투자효율', '부가가치율', '이윤분배율', '자본분배율',
#        '총자산회전율', '매출채권회전률', '당좌자산회전률', '유형자산회전율', '경영자본회전률', '총자본회전률',
#        '비유동자산회전률', '유동자산회전률', '영업년수', '쭈피처', '영업투자현금비율', '영업재무현금비율', '부실판단',
#        '도입기', '성숙기', '성장기', '쇠퇴기'],
#       dtype='object')

# %%
all_data = pd.concat([listed, unlisted], axis=0)
all_data
# Out:
#             회사명   거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0      (주)CMG제약   58820  2022             19.00              79.00
# 1       (주)ES큐브   50120  2020              3.00             270.00
# 2      (주)MH에탄올   23150  2022              6.00               9.00
# 3      (주)강원에너지  114190  2018            -16.00             -28.00
# 4      (주)고려시멘트  198440  2022              0.00               7.00
# ...         ...     ...   ...               ...                ...
# 20300  주식회사나노브릭   77738  2017            -14.23             -27.59
# 20301   주식회사나노아   67623  2017           -153.85               0.00
# 20302  주식회사나노앤텍   72817  2022              0.76               0.85
# 20303   주식회사나노코   56825  2022             28.06              38.70
# 20304   주식회사나노팜   29937  2019             29.25               0.00
#
#        CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율    유동비율    당좌비율     부채비율  ...  \
# 0                   2.00               6.00  617.00  520.00    15.00  ...
# ...

# %%
all_data = all_data[
    [
        "회사명",
        "거래소코드",
        "회계년도",
        "CASH FLOW 대 부채비율",
        "CASH FLOW 대 차입금비율",
        "CASH FLOW 대 총자본비율",
        "CASH FLOW 대 매출액비율",
        "유동비율",
        "당좌비율",
        "부채비율",
        "유동부채비율",
        "차입금의존도",
        "순운전자본비율",
        "현금비율",
        "유동자산구성비율",
        "자기자본구성비율",
        "자기자본순이익률",
        "경영자본순이익률",
        "매출액순이익률",
        "총자본사업이익률",
        "총자본영업이익률",
        "매출액영업이익률",
        "금융비용부담률",
        "CROE",
        "총자산증가율",
        "총자본증가율",
        "유동자산증가율",
        "비유동자산증가율",
        "매출액증가율",
        "유형자산증가율",
        "부가가치",
        "총자본투자효율",
        "설비투자효율",
        "부가가치율",
        "이윤분배율",
        "자본분배율",
        "총자산회전율",
        "매출채권회전률",
        "당좌자산회전률",
        "유형자산회전율",
        "경영자본회전률",
        "총자본회전률",
        "비유동자산회전률",
        "유동자산회전률",
        "영업년수",
        "쭈피처",
        "영업투자현금비율",
        "영업재무현금비율",
        "부실판단",
        "도입기",
        "성숙기",
        "성장기",
        "쇠퇴기",
    ]
]

# %%
all_data.to_csv('../1.데이터셋/Feature/All_Data.csv', index=False)
